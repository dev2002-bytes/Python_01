# %%
## Exception handling

a=b

# %%
## handle exception try,except block

try:
    a=b
except:
    print("the variable has been assigned")

# %%
try:
    a=b
except NameError as ex:
    print(ex)

# %%
result=1/0

# %%
try:
    result=1/0
except ZeroDivisionError as ex:
    print(ex)
    print("plz enter the dominator greater than zero")

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("plz enter the dominator greater than zero")

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("plz enter the dominator greater than zero")
except Exception as ex1:
    print(ex1)
    print("main exceptiion got caught here")

# %%
try:
    num=int(input("enter the number"))
    result=10/num
except ValueError:
    print("plz enter the valid number")
except ZeroDivisionError:
    print("plz enter the dominator greater than zero")

# %%
try:
    num=int(input("enter the number"))
    result=10/num
except ValueError:
    print("plz enter the valid number")
except ZeroDivisionError:
    print("plz enter the dominator greater than zero")

# %%
## try,except,else, block


try:
    num=int(input("enter the number"))
    result=10/num
except ValueError:
    print("plz enter the valid number")
except ZeroDivisionError:
    print("plz enter the dominator greater than zero")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")

# %%
## try,except,else, block


try:
    num=int(input("enter the number"))
    result=10/num
except ValueError:
    print("plz enter the valid number")
except ZeroDivisionError:
    print("plz enter the dominator greater than zero")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")

# %%
## try except else and finally block

try:
    num=int(input("enter the number"))
    result=10/num
except ValueError:

    print("plz enter the valid number")
except ZeroDivisionError:
    print("plz enter the dominator greater than zero")
except Exception as ex:
    print(ex)
    
else:
    print(f"the result is {result}")

finally:
    print("this block will always execute")

# %%
## try except else and finally block

try:
    num=int(input("enter the number"))
    result=10/num
except ValueError:

    print("plz enter the valid number")
except ZeroDivisionError:
    print("plz enter the dominator greater than zero")
except Exception as ex:
    print(ex)
    
else:
    print(f"the result is {result}")

finally:
    print("this block will always execute")

# %%
## file handling and execution handling

try:
    file=open("example.txt","r")
    print(file.read())

except FileNotFoundError:
    print("file not found")
finally:
    if 'file' in locals() and not file.closed():
       file.close()
       print("the file has been closed")

# %%
## file handling and execution handling

try:
    file=open("example.txt","r")
    content=file.read()
    a=b
    print(content)

except FileNotFoundError:
    print("file not found")
except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.closed():
       file.close()
       print("the file has been closed")
