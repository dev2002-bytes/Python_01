# %%
1+1

# %%
56+3666666

# %%
age=32
if age>30:
    print(age)
print (age)

# %%
c=0

while c<5:
    print(c)
    c=c+1

# %%
for num in range(1,99):
    if(num>1):
        for i in range(2,num):
            if (num%i==0):
                break
        else:
            print(num)

# %% [markdown]
# print prime numbers bw 1 to 100 (nested for loop)

# %%
for i in range(1,101):
    if i>1:
        for j in range(2,i):
            if i%j==0:
                break
        else:
            print(i)

# %%
num=2
while(num<=100):
    i=2
    while i<num:
        if num%i==0:
            break
        i=i+1
    if i==num:
        print(num) 
    num=num+1

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
set1.intersection_update(set2)
print(set1)

# %%
text="In this tutorial we are discussing about sets"
words=text.split()

unique_words=set(words)
print(unique_words)
print(len(unique_words))

# %%
empty_set={}
print(type(empty_set))


emptyset_2=set()
print(type(emptyset_2))

set_3={1,2}
print(type(set_3))

# %% [markdown]
# CREATING,ACCESSING AND MODIFYING DICTIONARIES

# %%
student={"name":"Dev","age":24,"grade":24}
print(student["age"])

student["age"]=32
student

student["address"]="india"
print(student)

del student["grade"]
student

keys=student.keys()
keys

values=student.values()
values

# %% [markdown]
# Shallow copy

# %%
student_copy=student
student_copy

print(student)
print(student_copy)

# %%
student["name"]="Dev2"
print(student)
print(student_copy)

# %%
student_copy1=student.copy()
print(student_copy1)
print(student)

# %%
student["name"]="Dev3"
print(student)
print(student_copy1)

# %%
print(student)
for keys in student.keys():
   print(keys)
print()
for values in student.values():
    print(values)  

print()
for keys,values in student.items():
    print(f"{keys}:{values}")

# %%
numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}
print(type(frequency))

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)

# %%
dict1={"a":1,"b":2}
dict2={"b":3,"c":4}

merged_dict={**dict1,**dict2}
print(merged_dict)

# %%
feedback=["great service", "very satisfied","could be better","excellent experience"]

feedback.append("not happy with service")

positive_feed_count=sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())

print(f"Positive feedback count: {positive_feed_count}")
print("user feedback")
for comment in feedback:
    print(f"{comment}")

# %% [markdown]
# FUNCTIONS

# %%
##SYNTAX

def function_name(parameters):
    """ Doc string """
    ##function body
    return expression

# %%
##why functions

num=24
if num%2==0:
    print("even")
else:
    print("odd")

# %%
def even_or_odd(num):
    if num%2==0:
        print("even")
    else:
        print("odd")    


## calling
even_or_odd(25)

# %% [markdown]
# functions with multiple para

# %%
def add(a,b):
    return a+b


add(5,6)
# Out:
# 11

# %% [markdown]
# default para

# %%
def greet(name):
    print(f"hello {name}")

greet("dev")
# Out:
# hello dev

# %%
def greet(name="Guest"):
    print(f"hello {name}")

greet("dev")   

greet()
# Out:
# hello dev
# hello Guest

# %% [markdown]
# Variable length arguments|

# %%
# def print_numbers(*dev)
## positional args
def print_numbers(*args):
    for number in args:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,7,8,"dev")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# dev

# %% [markdown]
# keyword arguments

# %%
## key value pairs(keyword args)
def print_details(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")

# %%
print_details(name="dev", age="24", country="usa")
# Out:
# name:dev
# age:24
# country:usa

# %%
def print_details(*args,**kwargs):
    for val in args:
        print(f"Positional arguments :{val}")

    for key,value in kwargs.items():
        print(f"{key}:{value}")

# %%
print_details(1,2,"bobzy",name="dev", age="24", country="usa")
# Out:
# Positional arguments :1
# Positional arguments :2
# Positional arguments :bobzy
# name:dev
# age:24
# country:usa

# %% [markdown]
# RETURN STATEMENTS

# %%
def multiply(a,b):
    return a*b,a

multiply(2,3)
# Out:
# (6, 2)

# %% [markdown]
# Calculate the total cost of items in a shopping cart

# %%
def calculate_total_cost(cart):
    total_cost=0
    for item in cart:
        total_cost+=item['price']*item['quantity']
    return total_cost 

## example cart data 
cart=[
{'name':'apple','price':0.5,'quantity':4},
{'name':'banana','price':0.3,'quantity':6},
{'name':'orange','price':0.7,'quantity':3},
]  

total_cost=calculate_total_cost(cart)
print (total_cost)
# Out:
# 5.8999999999999995

# %%
def count_word_frequency(file_path):
    word_count={}
    with open(file_path,'r') as file:
        for line in file:
            words=line.split()
            for word in words:
                word=word.lower().strip('.,!?:\'')
                word_count[word]=word_count.get(word,0)+1
    return word_count

filepath='sample.txt'
word_frequency=count_word_frequency(filepath) 
print(word_frequency)
# Out:
# {}
