# %%
with open('example.txt','r') as file:
     content=file.read()
     print(content)

# %%
#read a text file and count the no of lines,words and character

def count_text(filepath):
    with open(filepath, 'r') as file:
        lines=file.readlines()
        line_count =len(lines)
        word_count =sum(len(line.split()) for line in lines)
        char_count=sum(len(line) for line in lines)
    return line_count, word_count, char_count


filepath='example.txt'
lines,words,character = count_text(filepath)
print(f'Lines: {lines}, Words: {words}, Character: {character}')

# %%
## write and then read a file


with open('example.txt','w+') as file:
     file.write("mk builders\n")
     file.write('mkc tmlog ki')
     file.seek(0)
     content=file.read()
print(content)

# %%
## create a new directory
import os
new_directory="package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' create")

# %%
##listing files and dir
items=os.listdir('.')
print(items)

# %%
with open('example.txt','r') as file:
     content=file.read()
     print(content)

# %%
#read a text file and count the no of lines,words and character

def count_text(filepath):
    with open(filepath, 'r') as file:
        lines=file.readlines()
        line_count =len(lines)
        word_count =sum(len(line.split()) for line in lines)
        char_count=sum(len(line) for line in lines)
    return line_count, word_count, char_count


filepath='example.txt'
lines,words,character = count_text(filepath)
print(f'Lines: {lines}, Words: {words}, Character: {character}')

# %%
## write and then read a file


with open('example.txt','w+') as file:
     file.write("mk builders\n")
     file.write('mkc tmlog ki')
     file.seek(0)
     content=file.read()
print(content)

# %%
## create a new directory
import os
new_directory="package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' create")

# %%
##listing files and dir
items=os.listdir('.')
print(items)

# %%
with open('example.txt','r') as file:
     content=file.read()
     print(content)

# %%
#read a text file and count the no of lines,words and character

def count_text(filepath):
    with open(filepath, 'r') as file:
        lines=file.readlines()
        line_count =len(lines)
        word_count =sum(len(line.split()) for line in lines)
        char_count=sum(len(line) for line in lines)
    return line_count, word_count, char_count


filepath='example.txt'
lines,words,character = count_text(filepath)
print(f'Lines: {lines}, Words: {words}, Character: {character}')

# %%
## write and then read a file


with open('example.txt','w+') as file:
     file.write("mk builders\n")
     file.write('mkc tmlog ki')
     file.seek(0)
     content=file.read()
print(content)

# %%
## create a new directory
import os
new_directory="package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' create")

# %%
##listing files and dir
import os
items=os.listdir('.')
print(items)
# Out:
# ['example.bin', 'example.txt', 'fileoperation.ipynb', 'package']
